# %%
import math
import time

import cv2
import cvzone
from ultralytics import YOLO
# Out:
# Matplotlib is building the font cache; this may take a moment.
# /Users/nasr/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
confidence = 0.7

cap = cv2.VideoCapture(0)  # For Webcam
cap.set(3, 640)
cap.set(4, 480)
# cap = cv2.VideoCapture("")  # For Video
model = YOLO("best.pt")

classNames = ["fake", "real"]

prev_frame_time = 0
new_frame_time = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       5 cap.set(4, 480)
#       6 # cap = cv2.VideoCapture("")  # For Video
# ----> 7 model = YOLO("best.pt")
#       9 classNames = ["fake", "real"]
#      11 prev_frame_time = 0
#
# NameError: name 'YOLO' is not defined

# %%
while True:
    new_frame_time = time.time()
    success, img = cap.read()
    results = model(img, stream=True, verbose=False)
    for r in results:
        boxes = r.boxes
        for box in boxes:
            # Bounding Box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            # cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,255),3)
            w, h = x2 - x1, y2 - y1
            # Confidence
            conf = math.ceil((box.conf[0] * 100)) / 100
            # Class Name
            cls = int(box.cls[0])
            if conf > confidence:

                if classNames[cls] == 'real':
                    color = (0, 255, 0)
                elif classNames[cls]=='fake':
                    color = (0, 0, 255)

                cvzone.cornerRect(img, (x1, y1, w, h),colorC=color,colorR=color)
                cvzone.putTextRect(img, f'{classNames[cls].upper()} {int(conf*100)}%',
                                   (max(0, x1), max(35, y1)), scale=2, thickness=4,colorR=color,
                                   colorB=color)



    fps = 1 / (new_frame_time - prev_frame_time)
    prev_frame_time = new_frame_time
    print(fps)

    cv2.imshow("Image", img)
    cv2.waitKey(1)
# Out:
# 5.843050104639634e-10
# 1.7125102175636755
# 3.643694407065162
# 5.075035875991278
# 7.815730579950769
# 6.015969707183786
# 7.720278896488761
# 7.330853771078609
# 7.884756302742169
# 10.34448026083761
# 8.485632724572765
# 8.863121815772846
# 8.857244823617608
# 7.645677515790625
# 7.710925593306651
# 9.706565457869525
# 11.812545061283345
# 8.486645731490174
# 9.013553734637346
# 8.835172983266208
# 10.992399702277993
# 10.171387830624958
# 9.326105421378669
# 9.410704629847766
# 10.014406903088865
# 9.97952371095265
# 10.151791441067482
# 10.026064923268155
# 9.848419530108997
# 9.620669406928949
# 10.340960697828654
# 6.56253119479792
# 7.665827763491445
# 7.431465029996563
# 7.925130517099015
# 7.049902091789997
# 7.788214541031854
# 7.254635867544171
# 8.538023409669211
# 10.370748400241323
# 10.570375858749289
# 7.26380742087717
# 1.9065156837504273
# 7.10727926499046
# 6.627946923379597
# 5.728827819815883
# 7.064388395300854
# 7.2317082422394945
# 7.289687595046709
# 6.2978199470565
# 7.2327557664716915
# 6.696133478719685
# 5.143267761626695
# 6.532736074163141
# 7.509594897999377
# 7.670299767384021
# 7.090074952584123
# 8.289482369821673
# 6.636315450545313
# 6.470225083957195
# 7.423244717471678
# 7.129980977895941
# 6.656061750572881
# 6.790020009195164
# 7.212978981726381
# 5.5983769353977575
# 6.512459571798777
# 5.536304118268215
# 4.487259204419748
# 4.795359105662893
# 5.528984198586085
# 5.99369521539442
# 5.552964477636838
# 4.982287671216604
# 4.292376211684569
# 5.128106564943361
# 6.083568303918497
# 5.51310483340957

# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ultralytics
#   Downloading ultralytics-8.2.48-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 990.5 kB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from ultralytics) (1.26.4)
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Downloading matplotlib-3.9.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.31.0)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.2.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from ultralytics) (0.17.1)
# Collecting tqdm>=4.64.0 (from ultralytics)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from ultralytics) (5.9.8)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting pandas>=1.1.4 (from ultralytics)
#   Downloading pandas-2.2.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading contourpy-1.2.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->ultralytics)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->ultralytics)
#   Downloading fonttools-4.53.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib>=3.3.0->ultralytics)
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pytz>=2020.1 (from pandas>=1.1.4->ultralytics)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->ultralytics)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/nasr/Library/Python/3.9/lib/python/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.48-py3-none-any.whl (793 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.7/793.7 kB 6.5 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib-3.9.0-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 5.7 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.2-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 6.2 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 2.5 MB/s eta 0:00:0000:0100:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 3.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading contourpy-1.2.1-cp39-cp39-macosx_11_0_arm64.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.0/245.0 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp39-cp39-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 4.0 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 4.1 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pytz, py-cpuinfo, tzdata, tqdm, scipy, pyparsing, kiwisolver, importlib-resources, fonttools, cycler, contourpy, pandas, matplotlib, ultralytics-thop, seaborn, ultralytics
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 importlib-resources-6.4.0 kiwisolver-1.4.5 matplotlib-3.9.0 pandas-2.2.2 py-cpuinfo-9.0.0 pyparsing-3.1.2 pytz-2024.1 scipy-1.13.1 seaborn-0.13.2 tqdm-4.66.4 tzdata-2024.1 ultralytics-8.2.48 ultralytics-thop-2.0.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
